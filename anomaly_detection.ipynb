# %% [markdown]
# <a href="https://colab.research.google.com/github/lchebotarova/Anomaly_detection_DL/blob/main/anomaly_detection.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
import numpy as np
import glob
from sklearn import preprocessing
import matplotlib.pyplot as plt
import seaborn as sns
from sklearn.metrics import accuracy_score, precision_score, recall_score, f1_score, confusion_matrix

# %%
#For google colab
from google.colab import drive
drive.mount('/content/drive',force_remount=True)
#Your path
# %cd '/content/drive/MyDrive/DL/Project/'
# Out:
# Mounted at /content/drive
# /content/drive/MyDrive/DL/Project

# %%
#view of a sample of data
df=pd.read_csv("data/A1Benchmark/real_1.csv")
df
# Out:
#       timestamp     value  is_anomaly
# 0             1  0.000000           0
# 1             2  0.091758           0
# 2             3  0.172297           0
# 3             4  0.226219           0
# 4             5  0.176358           0
# ...         ...       ...         ...
# 1415       1416  0.159675           0
# 1416       1417  0.137626           0
# 1417       1418  0.197441           0
# 1418       1419  0.161966           0
# 1419       1420  0.111648           0
#
# [1420 rows x 3 columns]

# %%
#Convert 0 in value to NaN and drop
df['value'] = df['value'].replace(0, np.nan)
df = df.dropna(subset=['value'])
df.value = preprocessing.normalize([df.value]).T
# Out:
# <ipython-input-4-f679f6d9179a>:4: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df.value = preprocessing.normalize([df.value]).T

# %%
plt.plot(df.timestamp,df.value)
plt.xlabel("Timestamp")
plt.ylabel("NormalizedValue")
plt.title(" Example plot of web traffic after preprocessing ")
plt.show()

# %%
#function to convert dataframe to into 2d array
#creating sliding window of length 60 values in a sequence

def convert_2d(df):
    rows = []

    for i in range(len(df) - 59):
        segment = df.iloc[i:i+60]
        is_anomaly = segment['is_anomaly'].any()
        new_row = segment['value'].tolist() + [int(is_anomaly)]
        rows.append(new_row)
    data_frame = pd.DataFrame(rows)

    return data_frame

# %%
#test on sample
df2 = convert_2d(df)
df2
# Out:
#             0         1         2         3         4         5         6   \
# 0     0.023933  0.044939  0.059003  0.045998  0.023602  0.022068  0.017847
# 1     0.044939  0.059003  0.045998  0.023602  0.022068  0.017847  0.034768
# 2     0.059003  0.045998  0.023602  0.022068  0.017847  0.034768  0.022177
# 3     0.045998  0.023602  0.022068  0.017847  0.034768  0.022177  0.025319
# 4     0.023602  0.022068  0.017847  0.034768  0.022177  0.025319  0.008102
# ...        ...       ...       ...       ...       ...       ...       ...
# 1213  0.017441  0.015098  0.025371  0.008678  0.009982  0.022765  0.027482
# 1214  0.015098  0.025371  0.008678  0.009982  0.022765  0.027482  0.032185
# 1215  0.025371  0.008678  0.009982  0.022765  0.027482  0.032185  0.011102
# 1216  0.008678  0.009982  0.022765  0.027482  0.032185  0.011102  0.060374
# 1217  0.009982  0.022765  0.027482  0.032185  0.011102  0.060374  0.023431
#
#             7         8         9   ...        51        52        53  \
# 0     0.034768  0.022177  0.025319  ...  0.023166  0.014312  0.020640
# 1     0.022177  0.025319  0.008102  ...  0.014312  0.020640  0.042561
# 2     0.025319  0.008102  0.004625  ...  0.020640  0.042561  0.022618
# 3     0.008102  0.004625  0.016524  ...  0.042561  0.022618  0.019144
# 4     0.004625  0.016524  0.022919  ...  0.022618  0.019144  0.008544
# ...        ...       ...       ...  ...       ...       ...       ...
# 1213  0.032185  0.011102  0.060374  ...  0.011454  0.013848  0.053461
# 1214  0.011102  0.060374  0.023431  ...  0.013848  0.053461  0.009340
# 1215  0.060374  0.023431  0.019470  ...  0.053461  0.009340  0.008602
# 1216  0.023431  0.019470  0.025885  ...  0.009340  0.008602  0.021073
# 1217  0.019470  0.025885  0.030086  ...  0.008602  0.021073  0.049554
#
#             54        55        56        57        58        59  60
# 0     0.042561  0.022618  0.019144  0.008544  0.014318  0.017870   0
# 1     0.022618  0.019144  0.008544  0.014318  0.017870  0.013770   0
# 2     0.019144  0.008544  0.014318  0.017870  0.013770  0.006221   0
# 3     0.008544  0.014318  0.017870  0.013770  0.006221  0.019369   0
# 4     0.014318  0.017870  0.013770  0.006221  0.019369  0.006319   0
# ...        ...       ...       ...       ...       ...       ...  ..
# 1213  0.009340  0.008602  0.021073  0.049554  0.045743  0.041647   0
# 1214  0.008602  0.021073  0.049554  0.045743  0.041647  0.035896   0
# 1215  0.021073  0.049554  0.045743  0.041647  0.035896  0.051497   0
# 1216  0.049554  0.045743  0.041647  0.035896  0.051497  0.042245   0
# 1217  0.045743  0.041647  0.035896  0.051497  0.042245  0.029121   0
#
# [1218 rows x 61 columns]

# %%
#Import and concat all files
path = r'data/A1Benchmark' #set the path accordingly
all_files=glob.glob(path+"/*.csv")

# %%
preprocessed_dfs = []

for filename in all_files:
    df = pd.read_csv(filename, index_col=None, header=0)
    df['value'] = df['value'].replace(0, np.nan)
    df = df.dropna(subset=['value'])

    # Normalize the 'value' column
    normalized_values = preprocessing.normalize([df['value'].to_numpy()])[0]
    df['value'] = normalized_values

    preprocessed_dfs.append(df)

concatenated_df = pd.concat(preprocessed_dfs, axis=0, ignore_index=True)

# %%
concatenated_df
# Out:
#        timestamp     value  is_anomaly
# 0              1  0.117274           0
# 1              2  0.065254           0
# 2              3  0.035630           0
# 3              4  0.069953           0
# 4              5  0.023508           0
# ...          ...       ...         ...
# 92673       1435  0.057625           1
# 92674       1436  0.061902           1
# 92675       1437  0.061226           1
# 92676       1438  0.094766           1
# 92677       1439  0.085312           1
#
# [92678 rows x 3 columns]

# %%
concatenated_df['is_anomaly'].value_counts()
# Out:
# 0    91024
# 1     1654
# Name: is_anomaly, dtype: int64

# %%
1654/91024 *100
# Out:
# 1.8171031815784846

# %%
frame = convert_2d(concatenated_df)

# %%
frame
# Out:
#              0         1         2         3         4         5         6   \
# 0      0.117274  0.065254  0.035630  0.069953  0.023508  0.032052  0.025228
# 1      0.065254  0.035630  0.069953  0.023508  0.032052  0.025228  0.030400
# 2      0.035630  0.069953  0.023508  0.032052  0.025228  0.030400  0.028542
# 3      0.069953  0.023508  0.032052  0.025228  0.030400  0.028542  0.025995
# 4      0.023508  0.032052  0.025228  0.030400  0.028542  0.025995  0.027283
# ...         ...       ...       ...       ...       ...       ...       ...
# 92614  0.023860  0.021384  0.021384  0.032189  0.024761  0.020259  0.025436
# 92615  0.021384  0.021384  0.032189  0.024761  0.020259  0.025436  0.018683
# 92616  0.021384  0.032189  0.024761  0.020259  0.025436  0.018683  0.020034
# 92617  0.032189  0.024761  0.020259  0.025436  0.018683  0.020034  0.019808
# 92618  0.024761  0.020259  0.025436  0.018683  0.020034  0.019808  0.023860
#
#              7         8         9   ...        51        52        53  \
# 0      0.030400  0.028542  0.025995  ...  0.066689  0.038383  0.092724
# 1      0.028542  0.025995  0.027283  ...  0.038383  0.092724  0.104266
# 2      0.025995  0.027283  0.029525  ...  0.092724  0.104266  0.055304
# 3      0.027283  0.029525  0.022249  ...  0.104266  0.055304  0.116074
# 4      0.029525  0.022249  0.026978  ...  0.055304  0.116074  0.032219
# ...         ...       ...       ...  ...       ...       ...       ...
# 92614  0.018683  0.020034  0.019808  ...  0.022735  0.018908  0.016207
# 92615  0.020034  0.019808  0.023860  ...  0.018908  0.016207  0.023410
# 92616  0.019808  0.023860  0.026336  ...  0.016207  0.023410  0.020484
# 92617  0.023860  0.026336  0.024761  ...  0.023410  0.020484  0.036015
# 92618  0.026336  0.024761  0.019358  ...  0.020484  0.036015  0.061676
#
#              54        55        56        57        58        59  60
# 0      0.104266  0.055304  0.116074  0.032219  0.109890  0.075174   0
# 1      0.055304  0.116074  0.032219  0.109890  0.075174  0.032297   0
# 2      0.116074  0.032219  0.109890  0.075174  0.032297  0.032976   0
# 3      0.032219  0.109890  0.075174  0.032297  0.032976  0.048264   0
# 4      0.109890  0.075174  0.032297  0.032976  0.048264  0.020991   0
# ...         ...       ...       ...       ...       ...       ...  ..
# 92614  0.023410  0.020484  0.036015  0.061676  0.057850  0.057625   1
# 92615  0.020484  0.036015  0.061676  0.057850  0.057625  0.061902   1
# 92616  0.036015  0.061676  0.057850  0.057625  0.061902  0.061226   1
# 92617  0.061676  0.057850  0.057625  0.061902  0.061226  0.094766   1
# 92618  0.057850  0.057625  0.061902  0.061226  0.094766  0.085312   1
#
# [92619 rows x 61 columns]

# %%
frame[60].value_counts()
# Out:
# 0    82425
# 1    10194
# Name: 60, dtype: int64

# %%
frame.to_csv('final_dataset.csv', index=False)

# %%
frame=pd.read_csv("final_dataset.csv")
frame
# Out:
#               0         1         2         3         4         5         6  \
# 0      0.117274  0.065254  0.035630  0.069953  0.023508  0.032052  0.025228
# 1      0.065254  0.035630  0.069953  0.023508  0.032052  0.025228  0.030400
# 2      0.035630  0.069953  0.023508  0.032052  0.025228  0.030400  0.028542
# 3      0.069953  0.023508  0.032052  0.025228  0.030400  0.028542  0.025995
# 4      0.023508  0.032052  0.025228  0.030400  0.028542  0.025995  0.027283
# ...         ...       ...       ...       ...       ...       ...       ...
# 92614  0.023860  0.021384  0.021384  0.032189  0.024761  0.020259  0.025436
# 92615  0.021384  0.021384  0.032189  0.024761  0.020259  0.025436  0.018683
# 92616  0.021384  0.032189  0.024761  0.020259  0.025436  0.018683  0.020034
# 92617  0.032189  0.024761  0.020259  0.025436  0.018683  0.020034  0.019808
# 92618  0.024761  0.020259  0.025436  0.018683  0.020034  0.019808  0.023860
#
#               7         8         9  ...        51        52        53  \
# 0      0.030400  0.028542  0.025995  ...  0.066689  0.038383  0.092724
# 1      0.028542  0.025995  0.027283  ...  0.038383  0.092724  0.104266
# 2      0.025995  0.027283  0.029525  ...  0.092724  0.104266  0.055304
# 3      0.027283  0.029525  0.022249  ...  0.104266  0.055304  0.116074
# 4      0.029525  0.022249  0.026978  ...  0.055304  0.116074  0.032219
# ...         ...       ...       ...  ...       ...       ...       ...
# 92614  0.018683  0.020034  0.019808  ...  0.022735  0.018908  0.016207
# 92615  0.020034  0.019808  0.023860  ...  0.018908  0.016207  0.023410
# 92616  0.019808  0.023860  0.026336  ...  0.016207  0.023410  0.020484
# 92617  0.023860  0.026336  0.024761  ...  0.023410  0.020484  0.036015
# 92618  0.026336  0.024761  0.019358  ...  0.020484  0.036015  0.061676
#
#              54        55        56        57        58        59  60
# 0      0.104266  0.055304  0.116074  0.032219  0.109890  0.075174   0
# 1      0.055304  0.116074  0.032219  0.109890  0.075174  0.032297   0
# 2      0.116074  0.032219  0.109890  0.075174  0.032297  0.032976   0
# 3      0.032219  0.109890  0.075174  0.032297  0.032976  0.048264   0
# 4      0.109890  0.075174  0.032297  0.032976  0.048264  0.020991   0
# ...         ...       ...       ...       ...       ...       ...  ..
# 92614  0.023410  0.020484  0.036015  0.061676  0.057850  0.057625   1
# 92615  0.020484  0.036015  0.061676  0.057850  0.057625  0.061902   1
# 92616  0.036015  0.061676  0.057850  0.057625  0.061902  0.061226   1
# 92617  0.061676  0.057850  0.057625  0.061902  0.061226  0.094766   1
# 92618  0.057850  0.057625  0.061902  0.061226  0.094766  0.085312   1
#
# [92619 rows x 61 columns]

# %%
from keras.models import Sequential
from keras.layers import Dense,Reshape,Conv2D,Flatten,MaxPooling1D,Conv1D,LSTM
from keras import optimizers
from keras.utils import to_categorical

# %%
#Keras model for comparison
model_k=Sequential()
model_k.add(Conv1D(64, kernel_size=5, strides=1, padding='same', activation='tanh',input_shape=(60, 1)))
model_k.add(MaxPooling1D(pool_size=2, strides=2))
model_k.add(Conv1D(64, kernel_size=5, strides=1, padding='same', activation='tanh'))
model_k.add(MaxPooling1D(pool_size=2, strides=2))
model_k.add(Reshape((1,15*64)))
model_k.add(LSTM(64, activation='tanh',return_sequences='False'))
model_k.add(Flatten())
model_k.add(Dense(32, activation='tanh'))
model_k.add(Dense(2, activation='softmax'))
model_k.compile(loss='binary_crossentropy', optimizer='adam',metrics=['accuracy'])
model_k.summary()
# Out:
# Model: "sequential"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  conv1d (Conv1D)             (None, 60, 64)            384
#
#  max_pooling1d (MaxPooling1  (None, 30, 64)            0
#  D)
#
#  conv1d_1 (Conv1D)           (None, 30, 64)            20544
#
#  max_pooling1d_1 (MaxPoolin  (None, 15, 64)            0
#  g1D)
#
#  reshape (Reshape)           (None, 1, 960)            0
#
#  lstm (LSTM)                 (None, 1, 64)             262400
#
#  flatten (Flatten)           (None, 64)                0
#
#  dense (Dense)               (None, 32)                2080
#
#  dense_1 (Dense)             (None, 2)                 66
#
# =================================================================
# Total params: 285474 (1.09 MB)
# Trainable params: 285474 (1.09 MB)
# Non-trainable params: 0 (0.00 Byte)
# _________________________________________________________________

# %%
import torch
import torch.nn as nn
import torch.optim as optim
from torch.utils.data import DataLoader, TensorDataset

# %%
class CLSTM(nn.Module):
    def __init__(self):
        super(CLSTM, self).__init__()
        self.conv1 = nn.Conv1d(1, 64, kernel_size=5, stride=1, padding = 'same')
        self.pool = nn.MaxPool1d(2, stride=2)
        self.conv2 = nn.Conv1d(64, 64, kernel_size=5, stride=1, padding = 'same')
        self.lstm = nn.LSTM(input_size=960, hidden_size=64, batch_first=True)
        self.fc1 = nn.Linear(64, 32)
        self.fc2 = nn.Linear(32, 2)
        self.tanh = nn.Tanh()
        self.flatten = nn.Flatten()


    def forward(self, x):
        x = self.conv1(x)
        x = self.tanh(x)
        x = self.pool(x)

        x = self.conv2(x)
        x = self.tanh(x)
        x = self.pool(x)

        # Reshape for LSTM layer
        #x = x.permute(0, 2, 1)
        #x = x.reshape(x.size(0), 1, -1)
        x = x.view(x.size(0), 1, -1)
        x, _ = self.lstm(x)

        # Flatten the output for Dense layer
        #x = self.flatten(x)
        x = x.contiguous().view(x.size(0), -1)

        # Dense layers
        x = self.tanh(self.fc1(x))
        x = torch.softmax(self.fc2(x), dim=1)
        return x

# %%
y = frame.iloc[:, 60]
X = frame.iloc[:, 0:60]

# Train-test split
train_size = int(0.7 * len(X))
X_train = X[:train_size]
X_test = X[train_size:]
y_train = y[:train_size]
y_test = y[train_size:]

# %%
#reshaping the data
X_train = X_train.to_numpy().reshape(-1, 60, 1)
X_test = X_test.to_numpy().reshape(-1, 60, 1)
y_test = y_test.to_numpy()

# %%
#converting y_train to categorical
y_train = to_categorical(y_train)

# %%
#train the Keras model
history=model_k.fit(x=X_train, y=y_train, batch_size=512, epochs=100, verbose=2)
# Out:
# Epoch 1/100
# 127/127 - 7s - loss: 0.3654 - accuracy: 0.8886 - 7s/epoch - 59ms/step
# Epoch 2/100
# 127/127 - 1s - loss: 0.3254 - accuracy: 0.8941 - 704ms/epoch - 6ms/step
# Epoch 3/100
# 127/127 - 1s - loss: 0.3161 - accuracy: 0.8973 - 689ms/epoch - 5ms/step
# Epoch 4/100
# 127/127 - 1s - loss: 0.2934 - accuracy: 0.9074 - 662ms/epoch - 5ms/step
# Epoch 5/100
# 127/127 - 1s - loss: 0.2801 - accuracy: 0.9106 - 651ms/epoch - 5ms/step
# Epoch 6/100
# 127/127 - 1s - loss: 0.2784 - accuracy: 0.9099 - 768ms/epoch - 6ms/step
# Epoch 7/100
# 127/127 - 1s - loss: 0.2746 - accuracy: 0.9110 - 672ms/epoch - 5ms/step
# Epoch 8/100
# 127/127 - 1s - loss: 0.2698 - accuracy: 0.9132 - 676ms/epoch - 5ms/step
# Epoch 9/100
# 127/127 - 1s - loss: 0.2676 - accuracy: 0.9143 - 830ms/epoch - 7ms/step
# Epoch 10/100
# 127/127 - 1s - loss: 0.2634 - accuracy: 0.9161 - 1s/epoch - 8ms/step
# Epoch 11/100
# 127/127 - 1s - loss: 0.2586 - accuracy: 0.9181 - 921ms/epoch - 7ms/step
# Epoch 12/100
# 127/127 - 1s - loss: 0.2566 - accuracy: 0.9187 - 961ms/epoch - 8ms/step
# Epoch 13/100
# 127/127 - 1s - loss: 0.2535 - accuracy: 0.9201 - 1s/epoch - 8ms/step
# Epoch 14/100
# 127/127 - 1s - loss: 0.2516 - accuracy: 0.9209 - 999ms/epoch - 8ms/step
# Epoch 15/100
# 127/127 - 1s - loss: 0.2484 - accuracy: 0.9221 - 946ms/epoch - 7ms/step
# Epoch 16/100
# 127/127 - 1s - loss: 0.2466 - accuracy: 0.9225 - 702ms/epoch - 6ms/step
# Epoch 17/100
# 127/127 - 1s - loss: 0.2443 - accuracy: 0.9233 - 684ms/epoch - 5ms/step
# Epoch 18/100
# 127/127 - 1s - loss: 0.2413 - accuracy: 0.9243 - 707ms/epoch - 6ms/step
# Epoch 19/100
# 127/127 - 1s - loss: 0.2372 - accuracy: 0.9253 - 720ms/epoch - 6ms/step
# Epoch 20/100
# 127/127 - 1s - loss: 0.2336 - accuracy: 0.9266 - 689ms/epoch - 5ms/step
# Epoch 21/100
# 127/127 - 1s - loss: 0.2298 - accuracy: 0.9276 - 683ms/epoch - 5ms/step
# Epoch 22/100
# 127/127 - 1s - loss: 0.2244 - accuracy: 0.9292 - 688ms/epoch - 5ms/step
# Epoch 23/100
# 127/127 - 1s - loss: 0.2201 - accuracy: 0.9305 - 689ms/epoch - 5ms/step
# Epoch 24/100
# 127/127 - 1s - loss: 0.2150 - accuracy: 0.9313 - 696ms/epoch - 5ms/step
# Epoch 25/100
# 127/127 - 1s - loss: 0.2096 - accuracy: 0.9324 - 718ms/epoch - 6ms/step
# Epoch 26/100
# 127/127 - 1s - loss: 0.2048 - accuracy: 0.9333 - 710ms/epoch - 6ms/step
# Epoch 27/100
# 127/127 - 1s - loss: 0.1972 - accuracy: 0.9345 - 676ms/epoch - 5ms/step
# Epoch 28/100
# 127/127 - 1s - loss: 0.1895 - accuracy: 0.9368 - 686ms/epoch - 5ms/step
# Epoch 29/100
# 127/127 - 1s - loss: 0.1752 - accuracy: 0.9405 - 697ms/epoch - 5ms/step
# Epoch 30/100
# 127/127 - 1s - loss: 0.1626 - accuracy: 0.9435 - 908ms/epoch - 7ms/step
# Epoch 31/100
# 127/127 - 1s - loss: 0.1518 - accuracy: 0.9483 - 936ms/epoch - 7ms/step
# Epoch 32/100
# 127/127 - 1s - loss: 0.1427 - accuracy: 0.9512 - 936ms/epoch - 7ms/step
# Epoch 33/100
# 127/127 - 1s - loss: 0.1371 - accuracy: 0.9534 - 945ms/epoch - 7ms/step
# Epoch 34/100
# 127/127 - 1s - loss: 0.1249 - accuracy: 0.9577 - 950ms/epoch - 7ms/step
# Epoch 35/100
# 127/127 - 1s - loss: 0.1237 - accuracy: 0.9573 - 913ms/epoch - 7ms/step
# Epoch 36/100
# 127/127 - 1s - loss: 0.1164 - accuracy: 0.9613 - 843ms/epoch - 7ms/step
# Epoch 37/100
# 127/127 - 1s - loss: 0.1115 - accuracy: 0.9635 - 687ms/epoch - 5ms/step
# Epoch 38/100
# 127/127 - 1s - loss: 0.1076 - accuracy: 0.9645 - 746ms/epoch - 6ms/step
# Epoch 39/100
# 127/127 - 1s - loss: 0.1031 - accuracy: 0.9650 - 642ms/epoch - 5ms/step
# Epoch 40/100
# 127/127 - 1s - loss: 0.1026 - accuracy: 0.9654 - 704ms/epoch - 6ms/step
# Epoch 41/100
# 127/127 - 1s - loss: 0.0968 - accuracy: 0.9680 - 730ms/epoch - 6ms/step
# Epoch 42/100
# 127/127 - 1s - loss: 0.0958 - accuracy: 0.9681 - 666ms/epoch - 5ms/step
# Epoch 43/100
# 127/127 - 1s - loss: 0.0937 - accuracy: 0.9681 - 695ms/epoch - 5ms/step
# Epoch 44/100
# 127/127 - 1s - loss: 0.0901 - accuracy: 0.9698 - 733ms/epoch - 6ms/step
# Epoch 45/100
# 127/127 - 1s - loss: 0.0879 - accuracy: 0.9710 - 759ms/epoch - 6ms/step
# Epoch 46/100
# 127/127 - 1s - loss: 0.0877 - accuracy: 0.9701 - 725ms/epoch - 6ms/step
# Epoch 47/100
# 127/127 - 1s - loss: 0.0817 - accuracy: 0.9726 - 711ms/epoch - 6ms/step
# Epoch 48/100
# 127/127 - 1s - loss: 0.0773 - accuracy: 0.9741 - 672ms/epoch - 5ms/step
# Epoch 49/100
# 127/127 - 1s - loss: 0.0795 - accuracy: 0.9730 - 662ms/epoch - 5ms/step
# Epoch 50/100
# 127/127 - 1s - loss: 0.0768 - accuracy: 0.9741 - 773ms/epoch - 6ms/step
# Epoch 51/100
# 127/127 - 1s - loss: 0.0760 - accuracy: 0.9740 - 941ms/epoch - 7ms/step
# Epoch 52/100
# 127/127 - 1s - loss: 0.0757 - accuracy: 0.9747 - 970ms/epoch - 8ms/step
# Epoch 53/100
# 127/127 - 1s - loss: 0.0756 - accuracy: 0.9743 - 960ms/epoch - 8ms/step
# Epoch 54/100
# 127/127 - 1s - loss: 0.0705 - accuracy: 0.9759 - 1s/epoch - 8ms/step
# Epoch 55/100
# 127/127 - 1s - loss: 0.0732 - accuracy: 0.9752 - 956ms/epoch - 8ms/step
# Epoch 56/100
# 127/127 - 1s - loss: 0.0682 - accuracy: 0.9768 - 974ms/epoch - 8ms/step
# Epoch 57/100
# 127/127 - 1s - loss: 0.0664 - accuracy: 0.9776 - 667ms/epoch - 5ms/step
# Epoch 58/100
# 127/127 - 1s - loss: 0.0656 - accuracy: 0.9782 - 688ms/epoch - 5ms/step
# Epoch 59/100
# 127/127 - 1s - loss: 0.0649 - accuracy: 0.9777 - 671ms/epoch - 5ms/step
# Epoch 60/100
# 127/127 - 1s - loss: 0.0624 - accuracy: 0.9794 - 723ms/epoch - 6ms/step
# Epoch 61/100
# 127/127 - 1s - loss: 0.0651 - accuracy: 0.9777 - 695ms/epoch - 5ms/step
# Epoch 62/100
# 127/127 - 1s - loss: 0.0638 - accuracy: 0.9784 - 690ms/epoch - 5ms/step
# Epoch 63/100
# 127/127 - 1s - loss: 0.0592 - accuracy: 0.9798 - 719ms/epoch - 6ms/step
# Epoch 64/100
# 127/127 - 1s - loss: 0.0611 - accuracy: 0.9799 - 717ms/epoch - 6ms/step
# Epoch 65/100
# 127/127 - 1s - loss: 0.0580 - accuracy: 0.9799 - 670ms/epoch - 5ms/step
# Epoch 66/100
# 127/127 - 1s - loss: 0.0595 - accuracy: 0.9800 - 688ms/epoch - 5ms/step
# Epoch 67/100
# 127/127 - 1s - loss: 0.0571 - accuracy: 0.9806 - 728ms/epoch - 6ms/step
# Epoch 68/100
# 127/127 - 1s - loss: 0.0571 - accuracy: 0.9807 - 676ms/epoch - 5ms/step
# Epoch 69/100
# 127/127 - 1s - loss: 0.0577 - accuracy: 0.9805 - 698ms/epoch - 5ms/step
# Epoch 70/100
# 127/127 - 1s - loss: 0.0549 - accuracy: 0.9815 - 694ms/epoch - 5ms/step
# Epoch 71/100
# 127/127 - 1s - loss: 0.0563 - accuracy: 0.9806 - 962ms/epoch - 8ms/step
# Epoch 72/100
# 127/127 - 1s - loss: 0.0521 - accuracy: 0.9823 - 1s/epoch - 8ms/step
# Epoch 73/100
# 127/127 - 2s - loss: 0.0525 - accuracy: 0.9822 - 2s/epoch - 18ms/step
# Epoch 74/100
# 127/127 - 1s - loss: 0.0535 - accuracy: 0.9818 - 966ms/epoch - 8ms/step
# Epoch 75/100
# 127/127 - 1s - loss: 0.0536 - accuracy: 0.9823 - 1s/epoch - 8ms/step
# Epoch 76/100
# 127/127 - 1s - loss: 0.0509 - accuracy: 0.9826 - 747ms/epoch - 6ms/step
# Epoch 77/100
# 127/127 - 1s - loss: 0.0499 - accuracy: 0.9831 - 734ms/epoch - 6ms/step
# Epoch 78/100
# 127/127 - 1s - loss: 0.0530 - accuracy: 0.9819 - 658ms/epoch - 5ms/step
# Epoch 79/100
# 127/127 - 1s - loss: 0.0531 - accuracy: 0.9814 - 697ms/epoch - 5ms/step
# Epoch 80/100
# 127/127 - 1s - loss: 0.0478 - accuracy: 0.9838 - 730ms/epoch - 6ms/step
# Epoch 81/100
# 127/127 - 1s - loss: 0.0454 - accuracy: 0.9847 - 704ms/epoch - 6ms/step
# Epoch 82/100
# 127/127 - 1s - loss: 0.0457 - accuracy: 0.9840 - 668ms/epoch - 5ms/step
# Epoch 83/100
# 127/127 - 1s - loss: 0.0502 - accuracy: 0.9829 - 718ms/epoch - 6ms/step
# Epoch 84/100
# 127/127 - 1s - loss: 0.0474 - accuracy: 0.9835 - 708ms/epoch - 6ms/step
# Epoch 85/100
# 127/127 - 1s - loss: 0.0474 - accuracy: 0.9835 - 659ms/epoch - 5ms/step
# Epoch 86/100
# 127/127 - 1s - loss: 0.0459 - accuracy: 0.9845 - 706ms/epoch - 6ms/step
# Epoch 87/100
# 127/127 - 1s - loss: 0.0463 - accuracy: 0.9840 - 669ms/epoch - 5ms/step
# Epoch 88/100
# 127/127 - 1s - loss: 0.0445 - accuracy: 0.9840 - 699ms/epoch - 6ms/step
# Epoch 89/100
# 127/127 - 1s - loss: 0.0433 - accuracy: 0.9848 - 698ms/epoch - 5ms/step
# Epoch 90/100
# 127/127 - 1s - loss: 0.0454 - accuracy: 0.9838 - 914ms/epoch - 7ms/step
# Epoch 91/100
# 127/127 - 1s - loss: 0.0450 - accuracy: 0.9842 - 933ms/epoch - 7ms/step
# Epoch 92/100
# 127/127 - 1s - loss: 0.0432 - accuracy: 0.9848 - 898ms/epoch - 7ms/step
# Epoch 93/100
# 127/127 - 1s - loss: 0.0423 - accuracy: 0.9854 - 913ms/epoch - 7ms/step
# Epoch 94/100
# 127/127 - 1s - loss: 0.0421 - accuracy: 0.9851 - 975ms/epoch - 8ms/step
# Epoch 95/100
# 127/127 - 1s - loss: 0.0443 - accuracy: 0.9845 - 959ms/epoch - 8ms/step
# Epoch 96/100
# 127/127 - 1s - loss: 0.0428 - accuracy: 0.9854 - 863ms/epoch - 7ms/step
# Epoch 97/100
# 127/127 - 1s - loss: 0.0412 - accuracy: 0.9854 - 675ms/epoch - 5ms/step
# Epoch 98/100
# 127/127 - 1s - loss: 0.0383 - accuracy: 0.9866 - 680ms/epoch - 5ms/step
# Epoch 99/100
# 127/127 - 1s - loss: 0.0418 - accuracy: 0.9855 - 661ms/epoch - 5ms/step
# Epoch 100/100
# 127/127 - 1s - loss: 0.0440 - accuracy: 0.9845 - 670ms/epoch - 5ms/step

# %%
plt.plot(history.history['loss'])
plt.xlabel('epoch')
plt.ylabel('loss')
plt.show()

# %%
#convert to tensors
X_train_tensor = torch.Tensor(X_train).permute(0, 2, 1)
X_test_tensor = torch.Tensor(X_test).permute(0, 2, 1)
y_train_tensor = torch.Tensor(y_train)
y_test_tensor = torch.LongTensor(y_test)


# Create DataLoader
batch_size=512
train_dataset = TensorDataset(X_train_tensor, y_train_tensor)
train_loader = DataLoader(train_dataset, batch_size=batch_size, shuffle=True)
test_dataset = TensorDataset(X_test_tensor, y_test_tensor)
test_loader = DataLoader(test_dataset, batch_size=batch_size, shuffle=False)

# %%
model = CLSTM()

# %%
learning_rate = 0.001

# Loss function and optimizer
criterion = nn.BCELoss()
optimizer = optim.Adam(model.parameters(), lr = learning_rate)

# %%
def model_summary(model):
    print("Model Summary:")
    total_params = 0

    for name, parameter in model.named_parameters():
        param = parameter.numel()
        total_params += param
        if parameter.requires_grad:
            print(f"Layer: {name} | Size: {param} | Requires Grad: {parameter.requires_grad}")

    print(f"Total Parameters: {total_params}")

model_summary(model)
# Out:
# Model Summary:
# Layer: conv1.weight | Size: 320 | Requires Grad: True
# Layer: conv1.bias | Size: 64 | Requires Grad: True
# Layer: conv2.weight | Size: 20480 | Requires Grad: True
# Layer: conv2.bias | Size: 64 | Requires Grad: True
# Layer: lstm.weight_ih_l0 | Size: 245760 | Requires Grad: True
# Layer: lstm.weight_hh_l0 | Size: 16384 | Requires Grad: True
# Layer: lstm.bias_ih_l0 | Size: 256 | Requires Grad: True
# Layer: lstm.bias_hh_l0 | Size: 256 | Requires Grad: True
# Layer: fc1.weight | Size: 2048 | Requires Grad: True
# Layer: fc1.bias | Size: 32 | Requires Grad: True
# Layer: fc2.weight | Size: 64 | Requires Grad: True
# Layer: fc2.bias | Size: 2 | Requires Grad: True
# Total Parameters: 285730

# %%
device = torch.device("cuda" if torch.cuda.is_available() else "cpu")
model.to(device)
# Out:
# CLSTM(
#   (conv1): Conv1d(1, 64, kernel_size=(5,), stride=(1,), padding=same)
#   (pool): MaxPool1d(kernel_size=2, stride=2, padding=0, dilation=1, ceil_mode=False)
#   (conv2): Conv1d(64, 64, kernel_size=(5,), stride=(1,), padding=same)
#   (lstm): LSTM(960, 64, batch_first=True)
#   (fc1): Linear(in_features=64, out_features=32, bias=True)
#   (fc2): Linear(in_features=32, out_features=2, bias=True)
#   (tanh): Tanh()
#   (flatten): Flatten(start_dim=1, end_dim=-1)
# )

# %%
#Train Pytorch model
epochs = 100
max_grad_norm = 1.0

train_losses = []

for epoch in range(epochs):
    model.train()
    train_loss = 0
    for inputs, targets in train_loader:
        inputs, targets = inputs.to(device), targets.to(device)
        optimizer.zero_grad()
        outputs = model(inputs)
        loss = criterion(outputs, targets)
        loss.backward()
        torch.nn.utils.clip_grad_norm_(model.parameters(), max_grad_norm) #gradient clipping

        optimizer.step()
        train_loss += loss.item()

    avg_train_loss = train_loss / len(train_loader)
    train_losses.append(avg_train_loss)

    print(f'Epoch {epoch+1}, Training Loss: {avg_train_loss}')
# Out:
# Epoch 1, Training Loss: 0.3486059040535153
# Epoch 2, Training Loss: 0.3389069109451114
# Epoch 3, Training Loss: 0.33376767433534454
# Epoch 4, Training Loss: 0.319296674113574
# Epoch 5, Training Loss: 0.29621429964313356
# Epoch 6, Training Loss: 0.28101876436725376
# Epoch 7, Training Loss: 0.27506414654217365
# Epoch 8, Training Loss: 0.2707887968913777
# Epoch 9, Training Loss: 0.26689819123331954
# Epoch 10, Training Loss: 0.2645559734481526
# Epoch 11, Training Loss: 0.2632233263470056
# Epoch 12, Training Loss: 0.2591833843020942
# Epoch 13, Training Loss: 0.2561333754400569
# Epoch 14, Training Loss: 0.25252756781465424
# Epoch 15, Training Loss: 0.25107499804553085
# Epoch 16, Training Loss: 0.24988958004891404
# Epoch 17, Training Loss: 0.2437953886788661
# Epoch 18, Training Loss: 0.24040617553267893
# Epoch 19, Training Loss: 0.23773041942457515
# Epoch 20, Training Loss: 0.23663794489826742
# Epoch 21, Training Loss: 0.23145318653170519
# Epoch 22, Training Loss: 0.23043079850241893
# Epoch 23, Training Loss: 0.22519341005584387
# Epoch 24, Training Loss: 0.22113499174437184
# Epoch 25, Training Loss: 0.2189731681206095
# Epoch 26, Training Loss: 0.2151909255840647
# Epoch 27, Training Loss: 0.2104971383030959
# Epoch 28, Training Loss: 0.20772738250221792
# Epoch 29, Training Loss: 0.20290608363827384
# Epoch 30, Training Loss: 0.1993974561062385
# Epoch 31, Training Loss: 0.1940814006750978
# Epoch 32, Training Loss: 0.1890525190145012
# Epoch 33, Training Loss: 0.1827260110908606
# Epoch 34, Training Loss: 0.1811118053756361
# Epoch 35, Training Loss: 0.17471371608690953
# Epoch 36, Training Loss: 0.17048973384804614
# Epoch 37, Training Loss: 0.16408340251586567
# Epoch 38, Training Loss: 0.16191436338612414
# Epoch 39, Training Loss: 0.15460981645687358
# Epoch 40, Training Loss: 0.1485830222762476
# Epoch 41, Training Loss: 0.14299637431234824
# Epoch 42, Training Loss: 0.14001986378525186
# Epoch 43, Training Loss: 0.13263604549441751
# Epoch 44, Training Loss: 0.1278199994071262
# Epoch 45, Training Loss: 0.1306462548966483
# Epoch 46, Training Loss: 0.12215223902557779
# Epoch 47, Training Loss: 0.11497230833674979
# Epoch 48, Training Loss: 0.11167767743660709
# Epoch 49, Training Loss: 0.1114478582941641
# Epoch 50, Training Loss: 0.10778714543369812
# Epoch 51, Training Loss: 0.10485318552438669
# Epoch 52, Training Loss: 0.10651219457270593
# Epoch 53, Training Loss: 0.09634863230304455
# Epoch 54, Training Loss: 0.09644056475303305
# Epoch 55, Training Loss: 0.0946247924089901
# Epoch 56, Training Loss: 0.09086088660195119
# Epoch 57, Training Loss: 0.09095407227479567
# Epoch 58, Training Loss: 0.08697602393354957
# Epoch 59, Training Loss: 0.08540618536979194
# Epoch 60, Training Loss: 0.08921238794688165
# Epoch 61, Training Loss: 0.08389359026208637
# Epoch 62, Training Loss: 0.08151761926417275
# Epoch 63, Training Loss: 0.08495387417359615
# Epoch 64, Training Loss: 0.0813329348003301
# Epoch 65, Training Loss: 0.07953531444659383
# Epoch 66, Training Loss: 0.07456518125932986
# Epoch 67, Training Loss: 0.07356963007468877
# Epoch 68, Training Loss: 0.07301694618200692
# Epoch 69, Training Loss: 0.07695468591423485
# Epoch 70, Training Loss: 0.07039847770544487
# Epoch 71, Training Loss: 0.07143633403470666
# Epoch 72, Training Loss: 0.06697300173283562
# Epoch 73, Training Loss: 0.07077740684268981
# Epoch 74, Training Loss: 0.0668115189049657
# Epoch 75, Training Loss: 0.06541234043639475
# Epoch 76, Training Loss: 0.06762702107488171
# Epoch 77, Training Loss: 0.061087025490802103
# Epoch 78, Training Loss: 0.06404586206740281
# Epoch 79, Training Loss: 0.0632545689898213
# Epoch 80, Training Loss: 0.06063024692354709
# Epoch 81, Training Loss: 0.06332871213731334
# Epoch 82, Training Loss: 0.06460027679742321
# Epoch 83, Training Loss: 0.06489951621125063
# Epoch 84, Training Loss: 0.05576298421058129
# Epoch 85, Training Loss: 0.05618898648270002
# Epoch 86, Training Loss: 0.060404847706044755
# Epoch 87, Training Loss: 0.05579039826989174
# Epoch 88, Training Loss: 0.060980485678892436
# Epoch 89, Training Loss: 0.05848301074460266
# Epoch 90, Training Loss: 0.05955397053145048
# Epoch 91, Training Loss: 0.053854553806265505
# Epoch 92, Training Loss: 0.054248299919010146
# Epoch 93, Training Loss: 0.054113747097375826
# Epoch 94, Training Loss: 0.052210069870150935
# Epoch 95, Training Loss: 0.05080061817292388
# Epoch 96, Training Loss: 0.05316744183050835
# Epoch 97, Training Loss: 0.05116353650379369
# Epoch 98, Training Loss: 0.05036428852344123
# Epoch 99, Training Loss: 0.05379782938288422
# Epoch 100, Training Loss: 0.05871551590934983

# %%
# Plotting the training loss
plt.figure(figsize=(10, 5))
plt.plot(train_losses, label='Training Loss')
plt.xlabel('Epochs')
plt.ylabel('Loss')
plt.title('C-LSTM Training Loss')
plt.legend()
plt.show()

# %%
model.eval()

true_labels = []
predicted_labels = []
test_loss = 0.0
total_samples = 0

with torch.no_grad():
    for inputs, targets in test_loader:
      inputs = inputs.to(device)
      outputs = model(inputs)
      _, predicted = torch.max(outputs, 1)
      true_labels.extend(targets.cpu().numpy())
      predicted_labels.extend(predicted.cpu().numpy())
      test_loss += loss.item() * inputs.size(0)
      total_samples += inputs.size(0)


accuracy = accuracy_score(true_labels, predicted_labels)
precision = precision_score(true_labels, predicted_labels)
recall = recall_score(true_labels, predicted_labels)
f1 = f1_score(true_labels, predicted_labels)

average_test_loss = test_loss / total_samples

print(f'Test Loss: {average_test_loss:.4f}')


print(f'Accuracy: {accuracy:.4f}')
print(f'Precision: {precision:.4f}')
print(f'Recall: {recall:.4f}')
print(f'F1-score: {f1:.4f}')
# Out:
# Test Loss: 0.0388
# Accuracy: 0.9178
# Precision: 0.6646
# Recall: 0.6221
# F1-score: 0.6427

# %%
cm = confusion_matrix(true_labels, predicted_labels)

sns.heatmap(cm, annot=True, fmt='g', cmap='Blues')
plt.xlabel('Predicted')
plt.ylabel('Actual')
plt.title('Confusion matrix')
plt.show()
